# %% [markdown]
# ### Classificação de Diabetes utilizando Regressão Logística e Random Forest
#
# ### Realizando treinamento, avaliação e interpretação de modelos preditivos para classificação de diabetes, utilizando o dataset Pima Indians Diabetes.
#
# ### Os modelos implementados são: Regressão Logística e Random Forest, com pré-processamento completo, balanceamento de classes via SMOTE, análise exploratória de dados (EDA), avaliação com métricas de classificação e visualização da importância das features.

# %%
# Instalando requisitos
# !pip install pandas numpy matplotlib seaborn scikit-learn imbalanced-learn joblib openai imblearn pathlib dotenv
# Out:
# Requirement already satisfied: pandas in C:\Users\flmli\miniconda3\envs\music_genius\Lib\site-packages (3.0.0)
# Requirement already satisfied: numpy in C:\Users\flmli\miniconda3\envs\music_genius\Lib\site-packages (1.26.4)
# Requirement already satisfied: matplotlib in C:\Users\flmli\miniconda3\envs\music_genius\Lib\site-packages (3.10.8)
# Requirement already satisfied: seaborn in C:\Users\flmli\miniconda3\envs\music_genius\Lib\site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in C:\Users\flmli\miniconda3\envs\music_genius\Lib\site-packages (1.8.0)
# Requirement already satisfied: imbalanced-learn in C:\Users\flmli\miniconda3\envs\music_genius\Lib\site-packages (0.14.1)
# Requirement already satisfied: joblib in C:\Users\flmli\miniconda3\envs\music_genius\Lib\site-packages (1.5.3)
# Requirement already satisfied: openai in C:\Users\flmli\miniconda3\envs\music_genius\Lib\site-packages (2.17.0)
# Requirement already satisfied: imblearn in C:\Users\flmli\miniconda3\envs\music_genius\Lib\site-packages (0.0)
# Requirement already satisfied: pathlib in C:\Users\flmli\miniconda3\envs\music_genius\Lib\site-packages (1.0.1)
# Requirement already satisfied: dotenv in C:\Users\flmli\miniconda3\envs\music_genius\Lib\site-packages (0.9.9)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\flmli\miniconda3\envs\music_genius\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\flmli\miniconda3\envs\music_genius\Lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\flmli\miniconda3\envs\music_genius\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\flmli\miniconda3\envs\music_genius\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\flmli\miniconda3\envs\music_genius\Lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\flmli\miniconda3\envs\music_genius\Lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in C:\Users\flmli\miniconda3\envs\music_genius\Lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in C:\Users\flmli\miniconda3\envs\music_genius\Lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\flmli\miniconda3\envs\music_genius\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\flmli\miniconda3\envs\music_genius\Lib\site-packages (from scikit-learn) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\flmli\miniconda3\envs\music_genius\Lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: sklearn-compat<0.2,>=0.1.5 in C:\Users\flmli\miniconda3\envs\music_genius\Lib\site-packages (from imbalanced-learn) (0.1.5)
# Requirement already satisfied: anyio<5,>=3.5.0 in C:\Users\flmli\miniconda3\envs\music_genius\Lib\site-packages (from openai) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Users\flmli\miniconda3\envs\music_genius\Lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\flmli\miniconda3\envs\music_genius\Lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in C:\Users\flmli\miniconda3\envs\music_genius\Lib\site-packages (from openai) (0.13.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in C:\Users\flmli\miniconda3\envs\music_genius\Lib\site-packages (from openai) (2.12.5)
# Requirement already satisfied: sniffio in C:\Users\flmli\miniconda3\envs\music_genius\Lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in C:\Users\flmli\miniconda3\envs\music_genius\Lib\site-packages (from openai) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in C:\Users\flmli\miniconda3\envs\music_genius\Lib\site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in C:\Users\flmli\miniconda3\envs\music_genius\Lib\site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in C:\Users\flmli\miniconda3\envs\music_genius\Lib\site-packages (from httpx<1,>=0.23.0->openai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in C:\Users\flmli\miniconda3\envs\music_genius\Lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\flmli\miniconda3\envs\music_genius\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\flmli\miniconda3\envs\music_genius\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\Users\flmli\miniconda3\envs\music_genius\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\flmli\miniconda3\envs\music_genius\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: python-dotenv in C:\Users\flmli\miniconda3\envs\music_genius\Lib\site-packages (from dotenv) (1.2.1)
# Requirement already satisfied: six>=1.5 in C:\Users\flmli\miniconda3\envs\music_genius\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: colorama in C:\Users\flmli\miniconda3\envs\music_genius\Lib\site-packages (from tqdm>4->openai) (0.4.6)

# %%
#Import bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import os

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
from imblearn.over_sampling import SMOTE  # Para lidar com desbalanceamento

#Carregando o dataset Salvo localmente na máquina (o arquivo está dentro da pasta data, porém, é necessário colocar o caminho anterior com de acordo aonde foi salvo na sua máquina)
df = pd.read_csv('./data/diabetes.csv')

# %%
############    inspecionando os dados    ############
print(df.head())
print(df.info())
print(df.describe())

sns.countplot(x='Outcome', data=df)
plt.title("Distribuição de Outcome")
plt.show()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# <class 'pandas.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB
# None
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000
# 2026-02-06 10:55:07,854 | INFO | matplotlib.category | Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-02-06 10:55:07,857 | INFO | matplotlib.category | Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %% [markdown]
#   Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72             35        0  33.6                     0.627   50        1
# 1            1       85             66             29        0  26.6                     0.351   31        0
# 2            8      183             64              0        0  23.3                     0.672   32        1
# 3            1       89             66             23       94  28.1                     0.167   21        0
# 4            0      137             40             35      168  43.1                     2.288   33        1

# %% [markdown]
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin         BMI  DiabetesPedigreeFunction         Age     Outcome
# count   768.000000  768.000000     768.000000     768.000000  768.000000  768.000000                768.000000  768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479   31.992578                  0.471876   33.240885    0.348958
# std       3.369578   31.972618      19.355807      15.952218  115.244002    7.884160                  0.331329   11.760232    0.476951
# min       0.000000    0.000000       0.000000       0.000000    0.000000    0.000000                  0.078000   21.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000   27.300000                  0.243750   24.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000   32.000000                  0.372500   29.000000    0.000000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000   36.600000                  0.626250   41.000000    1.000000
# max      17.000000  199.000000     122.000000      99.000000  846.000000   67.100000                  2.420000   81.000000    1.000000

# %% [markdown]
# Carregando mapa de Correlação, para verificar quais dados tem mais relação com outro,
# exemplo, quando uma pessoa tem diabetes, se ela tem a glicose alta, a espessura da pele também aumenta,
# esse mapa valida esse tipo de detalhe

# %%
# -----------------------------
#    Mapa de Correlação
# -----------------------------
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title("Mapa de Correlação")
plt.show()

# %% [markdown]
# Algumas colunas do dataset contêm o valor 0, mas nesse contexto, 0 não representa um resultado real,
# e sim a ausência de medição (ex.: zero de Insulina ou BMI não faz sentido fisiologicamente).
# Portanto, substituímos os zeros por NaN (not a number).
# Em seguida, preenchemos esses valores nulos com a mediana da coluna, preservando a distribuição dos dados
# e evitando distorções que poderiam prejudicar o treinamento do modelo.
# Por fim, padronizamos as features usando StandardScaler, facilitando a convergência e o desempenho dos modelos de Machine Learning.

# %%
############    Normalizando os dados    ############
cols_zero = ['Glucose','BloodPressure','SkinThickness','Insulin','BMI']
df[cols_zero] = df[cols_zero].replace(0, np.nan)
print(df.isnull().sum())
df.fillna(df.median(), inplace=True)

X = df.drop('Outcome', axis=1)
y = df['Outcome']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %% [markdown]
# ao utilizar o "print(df.isnull()), estamos somando quantos itens nulos temos por coluna, que resulta assim:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
# -----------------------------
#    Dividindo treino e teste
# -----------------------------
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42, stratify=y
)

# %%
# -----------------------------
#  lidando com o desbalanceamento
# -----------------------------
smote = SMOTE(random_state=42)
X_train_res, y_train_res = smote.fit_resample(X_train, y_train)

# %%
# -----------------------------
#   Parte de treinamento
# -----------------------------
lr = LogisticRegression(random_state=42)
lr.fit(X_train_res, y_train_res)
y_pred_lr = lr.predict(X_test)

rf = RandomForestClassifier(random_state=42, n_estimators=100)
rf.fit(X_train_res, y_train_res)
y_pred_rf = rf.predict(X_test)

# %%
############   Salvando os modelos treinados    ############
#insira o caminho para salvar o modelo
os.makedirs('outputs', exist_ok=True)

joblib.dump(lr, './outputs/lr_model.pkl')
joblib.dump(rf, './outputs/rf_model.pkl')
joblib.dump(scaler, './outputs/scaler.pkl')
# Out:
# ['./outputs/scaler.pkl']

# %% [markdown]
# A função avaliar_modelo mostra métricas de classificação (accuracy, precision, recall e F1-score)
# e plota a matriz de confusão do modelo.
# A matriz ajuda a entender quantos casos foram classificados corretamente (verdadeiros positivos/negativos)
# e quantos foram classificados incorretamente (falsos positivos/negativos).

# %%
def avaliar_modelo(y_true, y_pred, modelo_name):
    print(f"Resultados para {modelo_name}:")
    print(classification_report(y_true, y_pred))
    cm = confusion_matrix(y_true, y_pred)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title(f"Matriz de Confusão - {modelo_name}")
    plt.xlabel("Predito")
    plt.ylabel("Real")
    plt.show()
    
avaliar_modelo(y_test, y_pred_lr, "Regressão Logística")
avaliar_modelo(y_test, y_pred_rf, "Random Forest")
# Out:
# Resultados para Regressão Logística:
#               precision    recall  f1-score   support
#
#            0       0.81      0.74      0.77       100
#            1       0.59      0.69      0.63        54
#
#     accuracy                           0.72       154
#    macro avg       0.70      0.71      0.70       154
# weighted avg       0.73      0.72      0.72       154
# Resultados para Random Forest:
#               precision    recall  f1-score   support
#
#            0       0.82      0.75      0.79       100
#            1       0.60      0.70      0.65        54
#
#     accuracy                           0.73       154
#    macro avg       0.71      0.73      0.72       154
# weighted avg       0.75      0.73      0.74       154

# %% [markdown]
# Agora que finalizamos a parte de análise, limpeza/normalização e treinamento,
# vamos testar o modelo!

# %%
# Carregar dataset original novamente (apenas para referencias e medianas)
#Essas medianas são usadas para preencher valores nulos (ou zeros) inseridos pelo usuário.
df = pd.read_csv('./data/diabetes.csv')

# %% [markdown]
# ### Treinamento via Algoritmo Genético
# Pode ser encontrado também em src/treinamento.py

# %%
# FUNÇÃO FITNESS

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, recall_score, f1_score
from imblearn.over_sampling import SMOTE
from utils import medir_tempo
import logging
import sys
from pathlib import Path
import pathlib
import pandas as pd
import joblib
import random
import time

try:
    BASE_DIR = pathlib.Path(__file__).resolve().parent.parent
except NameError:
    BASE_DIR = pathlib.Path.cwd().resolve()

DATA_DIR = BASE_DIR / "data"
OUTPUT_DIR = BASE_DIR / "outputs"

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s | %(levelname)s | %(name)s | %(message)s",
    handlers=[
        logging.StreamHandler(sys.stdout),      # Azure / Docker
        logging.FileHandler("pipeline.log")     # Local
    ]
)

logger = logging.getLogger("treinamento")
logger.info("===== INICIO DA EXECUCAO =====")

def fitness(model, X, y):
    try:
        scores = cross_val_score(model, X, y, cv=3, scoring="f1")
        logger.info(f"Fitness calculado: {scores.mean():.4f}")
        return scores.mean()
    except Exception as e:
        logger.error(f"Erro ao calcular fitness: {e}")
        return 0


#  CARREGAMENTO E PREPARAÇÃO

logger.info("Carregando dataset...")

try:
    df = pd.read_csv(DATA_DIR / "diabetes.csv")
except Exception as e:
    logger.exception("Erro ao carregar dataset")
    raise e

logger.info(f"Dataset carregado com {df.shape[0]} linhas e {df.shape[1]} colunas.")

cols_zero = ['Glucose','BloodPressure','SkinThickness','Insulin','BMI']
df[cols_zero] = df[cols_zero].replace(0, np.nan)
df.fillna(df.median(), inplace=True)


#  FUNÇÃO PROCESSAMENTO EM LOTES

@medir_tempo("treinamento_random_forest")
def processar_em_lotes(dataset, lote_inicial=150):
    """
    Processa o dataset em lotes simulando carga variável.
    """

    lote = lote_inicial
    dados_processados = []

    logger.info("Iniciando processamento em lotes...")

    for inicio in range(0, len(dataset), lote):
        fim = min(inicio + lote, len(dataset))
        lote_df = dataset.iloc[inicio:fim]

        logger.info(f"Processando lote {inicio//lote + 1} -> linhas {inicio} a {fim}")

        # simula maior carga — aumentando lote dinamicamente
        if len(lote_df) > 120:
            lote += 50
            logger.info(f"Carga alta detectada — aumentando lote para {lote}")
        else:
            lote = max(100, lote - 20)
            logger.info(f"Carga baixa — reduzindo lote para {lote}")

        dados_processados.append(lote_df)

    logger.info("Processamento em lotes finalizado.")
    return pd.concat(dados_processados, axis=0)

df = processar_em_lotes(df)


#  CONTINUA PREPARAÇÃO NORMAL

X = df.drop("Outcome", axis=1)
y = df["Outcome"]

logger.info("Normalizando variáveis...")
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

logger.info("Separando treino e teste...")
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42, stratify=y
)

logger.info("Aplicando SMOTE (balanceamento)...")
smote = SMOTE(random_state=42)
X_train_res, y_train_res = smote.fit_resample(X_train, y_train)

logger.info("Dados preparados com sucesso.")


# TREINAMENTO MODELOS 

logger.info("Treinando modelos base...")

lr_base = LogisticRegression(max_iter=500, random_state=42)
rf_base = RandomForestClassifier(n_estimators=100, random_state=42)

lr_base.fit(X_train_res, y_train_res)
rf_base.fit(X_train_res, y_train_res)

y_pred_lr = lr_base.predict(X_test)
y_pred_rf = rf_base.predict(X_test)

logger.info(
    f"BASE LR -> acc={accuracy_score(y_test,y_pred_lr):.3f} "
    f"recall={recall_score(y_test,y_pred_lr):.3f} "
    f"f1={f1_score(y_test,y_pred_lr):.3f}"
)

logger.info(
    f"BASE RF -> acc={accuracy_score(y_test,y_pred_rf):.3f} "
    f"recall={recall_score(y_test,y_pred_rf):.3f} "
    f"f1={f1_score(y_test,y_pred_rf):.3f}"
)

logger.info({
    "evento": "metricas_finais",
    "modelo": "RandomForest_Otimizado",
    "accuracy": accuracy_score,
    "recall": recall_score,
    "f1": f1_score
})


# ALGORITMO GENÉTICO

def gerar_individuo():
    return {
        "n_estimators": random.randint(50, 200),
        "max_depth": random.choice([None, 4, 6, 8, 10]),
        "min_samples_split": random.randint(2, 10)
    }

def mutacao(ind):
    logger.info(f"Mutacao aplicada no individuo: {ind}")
    if random.random() < 0.5:
        ind["n_estimators"] = random.randint(50, 200)
    else:
        ind["min_samples_split"] = random.randint(2, 10)
    return ind

@medir_tempo("treinamento_random_forest")
def crossover(pai, mae):
    filho = {}
    for k in pai:
        filho[k] = random.choice([pai[k], mae[k]])
    logger.info(f"Crossover gerou filho: {filho}")
    return filho


logger.info("Iniciando otimizacao genetica...")

POP = 5
GERACOES = 3

populacao = [gerar_individuo() for _ in range(POP)]

inicio = time.time()

for g in range(GERACOES):
    logger.info(f"--- Geracao {g+1}/{GERACOES} ---")

    avaliacoes = []

    for individuo in populacao:
        logger.info(f"Avaliando individuo: {individuo}")

        modelo = RandomForestClassifier(
            n_estimators=individuo["n_estimators"],
            max_depth=individuo["max_depth"],
            min_samples_split=individuo["min_samples_split"],
            random_state=42
        )

        score = fitness(modelo, X_train_res, y_train_res)
        avaliacoes.append((score, individuo))

    avaliacoes.sort(reverse=True, key=lambda x: x[0])
    melhores = avaliacoes[:3]

    logger.info(f"Melhor indivíduo da geracao: {melhores[0]}")

    nova_pop = [i[1] for i in melhores]

    while len(nova_pop) < POP:
        pai, mae = random.sample(melhores, 2)
        filho = crossover(pai[1], mae[1])
        filho = mutacao(filho)
        nova_pop.append(filho)

    populacao = nova_pop

fim = time.time()
logger.info(f"Tempo total de execucao do GA: {(fim - inicio):.2f} segundos")


# TREINO COM MELHOR MODELO

best_params = melhores[0][1]
logger.info(f"Melhores parametros encontrados: {best_params}")

rf_otimizado = RandomForestClassifier(**best_params, random_state=42)

rf_otimizado.fit(X_train_res, y_train_res)
y_pred_rf_opt = rf_otimizado.predict(X_test)

logger.info(
    f"OTIMIZADO RF -> acc={accuracy_score(y_test,y_pred_rf_opt):.3f} "
    f"recall={recall_score(y_test,y_pred_rf_opt):.3f} "
    f"f1={f1_score(y_test,y_pred_rf_opt):.3f}"
)


# SALVAR MODELOS

os.makedirs(OUTPUT_DIR, exist_ok=True)

joblib.dump(lr_base, OUTPUT_DIR /"lr_model.pkl")
joblib.dump(rf_base, OUTPUT_DIR / "rf_model.pkl")
joblib.dump(rf_otimizado, OUTPUT_DIR / "rf_optimized.pkl")
joblib.dump(scaler, OUTPUT_DIR / "scaler.pkl")

logger.info("Modelos salvos com sucesso!")
logger.info("===== FIM DA EXECUCAO =====")
# Out:
# 2026-02-06 10:55:08,270 | INFO | treinamento | ===== INICIO DA EXECUCAO =====
# 2026-02-06 10:55:08,271 | INFO | treinamento | Carregando dataset...
# 2026-02-06 10:55:08,273 | INFO | treinamento | Dataset carregado com 768 linhas e 9 colunas.
# 2026-02-06 10:55:08,276 | INFO | treinamento | Iniciando processamento em lotes...
# 2026-02-06 10:55:08,276 | INFO | treinamento | Processando lote 1 -> linhas 0 a 150
# 2026-02-06 10:55:08,276 | INFO | treinamento | Carga alta detectada — aumentando lote para 200
# 2026-02-06 10:55:08,276 | INFO | treinamento | Processando lote 1 -> linhas 150 a 350
# 2026-02-06 10:55:08,277 | INFO | treinamento | Carga alta detectada — aumentando lote para 250
# 2026-02-06 10:55:08,277 | INFO | treinamento | Processando lote 2 -> linhas 300 a 550
# 2026-02-06 10:55:08,277 | INFO | treinamento | Carga alta detectada — aumentando lote para 300
# 2026-02-06 10:55:08,279 | INFO | treinamento | Processando lote 2 -> linhas 450 a 750
# 2026-02-06 10:55:08,279 | INFO | treinamento | Carga alta detectada — aumentando lote para 350
# 2026-02-06 10:55:08,279 | INFO | treinamento | Processando lote 2 -> linhas 600 a 768
# 2026-02-06 10:55:08,279 | INFO | treinamento | Carga alta detectada — aumentando lote para 400
# 2026-02-06 10:55:08,279 | INFO | treinamento | Processando lote 2 -> linhas 750 a 768
# 2026-02-06 10:55:08,280 | INFO | treinamento | Carga baixa — reduzindo lote para 380
# 2026-02-06 10:55:08,280 | INFO | treinamento | Processamento em lotes finalizado.
# 2026-02-06 10:55:08,282 | INFO | root | ETAPA=treinamento_random_forest | TEMPO=0.00s
# 2026-02-06 10:55:08,282 | INFO | treinamento | Normalizando variáveis...
# 2026-02-06 10:55:08,284 | INFO | treinamento | Separando treino e teste...
# 2026-02-06 10:55:08,285 | INFO | treinamento | Aplicando SMOTE (balanceamento)...
# 2026-02-06 10:55:08,287 | INFO | treinamento | Dados preparados com sucesso.
# 2026-02-06 10:55:08,289 | INFO | treinamento | Treinando modelos base...
# 2026-02-06 10:55:08,397 | INFO | treinamento | BASE LR -> acc=0.729 recall=0.730 f1=0.647
# 2026-02-06 10:55:08,399 | INFO | treinamento | BASE RF -> acc=0.904 recall=0.865 f1=0.859
# 2026-02-06 10:55:08,399 | INFO | treinamento | {'evento': 'metricas_finais', 'modelo': 'RandomForest_Otimizado', 'accuracy': <function accuracy_score at 0x0000012CA235D580>, 'recall': <function recall_score at 0x0000012CA235E7A0>, 'f1': <function f1_score at 0x0000012CA235DE40>}
# 2026-02-06 10:55:08,401 | INFO | treinamento | Iniciando otimizacao genetica...
# 2026-02-06 10:55:08,401 | INFO | treinamento | --- Geracao 1/3 ---
# 2026-02-06 10:55:08,402 | INFO | treinamento | Avaliando individuo: {'n_estimators': 127, 'max_depth': 8, 'min_samples_split': 9}
# 2026-02-06 10:55:08,699 | INFO | treinamento | Fitness calculado: 0.8369
# 2026-02-06 10:55:08,701 | INFO | treinamento | Avaliando individuo: {'n_estimators': 99, 'max_depth': 6, 'min_samples_split': 8}
# 2026-02-06 10:55:08,921 | INFO | treinamento | Fitness calculado: 0.8304
# 2026-02-06 10:55:08,922 | INFO | treinamento | Avaliando individuo: {'n_estimators': 166, 'max_depth': 4, 'min_samples_split': 7}
# 2026-02-06 10:55:09,265 | INFO | treinamento | Fitness calculado: 0.8202
# 2026-02-06 10:55:09,265 | INFO | treinamento | Avaliando individuo: {'n_estimators': 102, 'max_depth': 8, 'min_samples_split': 8}
# 2026-02-06 10:55:09,514 | INFO | treinamento | Fitness calculado: 0.8407
# 2026-02-06 10:55:09,516 | INFO | treinamento | Avaliando individuo: {'n_estimators': 57, 'max_depth': 10, 'min_samples_split': 10}
# 2026-02-06 10:55:09,667 | INFO | treinamento | Fitness calculado: 0.8451
# 2026-02-06 10:55:09,667 | INFO | treinamento | Melhor indivíduo da geracao: (0.8450725746063631, {'n_estimators': 57, 'max_depth': 10, 'min_samples_split': 10})
# 2026-02-06 10:55:09,668 | INFO | treinamento | Crossover gerou filho: {'n_estimators': 102, 'max_depth': 8, 'min_samples_split': 9}
# 2026-02-06 10:55:09,669 | INFO | root | ETAPA=treinamento_random_forest | TEMPO=0.00s
# 2026-02-06 10:55:09,669 | INFO | treinamento | Mutacao aplicada no individuo: {'n_estimators': 102, 'max_depth': 8, 'min_samples_split': 9}
# 2026-02-06 10:55:09,669 | INFO | treinamento | Crossover gerou filho: {'n_estimators': 57, 'max_depth': 10, 'min_samples_split': 9}
# 2026-02-06 10:55:09,670 | INFO | root | ETAPA=treinamento_random_forest | TEMPO=0.00s
# 2026-02-06 10:55:09,670 | INFO | treinamento | Mutacao aplicada no individuo: {'n_estimators': 57, 'max_depth': 10, 'min_samples_split': 9}
# 2026-02-06 10:55:09,670 | INFO | treinamento | --- Geracao 2/3 ---
# 2026-02-06 10:55:09,671 | INFO | treinamento | Avaliando individuo: {'n_estimators': 57, 'max_depth': 10, 'min_samples_split': 10}
# 2026-02-06 10:55:09,820 | INFO | treinamento | Fitness calculado: 0.8451
# 2026-02-06 10:55:09,822 | INFO | treinamento | Avaliando individuo: {'n_estimators': 102, 'max_depth': 8, 'min_samples_split': 8}
# 2026-02-06 10:55:10,074 | INFO | treinamento | Fitness calculado: 0.8407
# 2026-02-06 10:55:10,075 | INFO | treinamento | Avaliando individuo: {'n_estimators': 127, 'max_depth': 8, 'min_samples_split': 9}
# 2026-02-06 10:55:10,397 | INFO | treinamento | Fitness calculado: 0.8369
# 2026-02-06 10:55:10,397 | INFO | treinamento | Avaliando individuo: {'n_estimators': 84, 'max_depth': 8, 'min_samples_split': 9}
# 2026-02-06 10:55:10,606 | INFO | treinamento | Fitness calculado: 0.8389
# 2026-02-06 10:55:10,606 | INFO | treinamento | Avaliando individuo: {'n_estimators': 57, 'max_depth': 10, 'min_samples_split': 5}
# 2026-02-06 10:55:10,771 | INFO | treinamento | Fitness calculado: 0.8597
# 2026-02-06 10:55:10,772 | INFO | treinamento | Melhor indivíduo da geracao: (0.8597069413911519, {'n_estimators': 57, 'max_depth': 10, 'min_samples_split': 5})
# 2026-02-06 10:55:10,772 | INFO | treinamento | Crossover gerou filho: {'n_estimators': 57, 'max_depth': 8, 'min_samples_split': 10}
# 2026-02-06 10:55:10,772 | INFO | root | ETAPA=treinamento_random_forest | TEMPO=0.00s
# 2026-02-06 10:55:10,772 | INFO | treinamento | Mutacao aplicada no individuo: {'n_estimators': 57, 'max_depth': 8, 'min_samples_split': 10}
# 2026-02-06 10:55:10,772 | INFO | treinamento | Crossover gerou filho: {'n_estimators': 57, 'max_depth': 10, 'min_samples_split': 5}
# 2026-02-06 10:55:10,774 | INFO | root | ETAPA=treinamento_random_forest | TEMPO=0.00s
# 2026-02-06 10:55:10,774 | INFO | treinamento | Mutacao aplicada no individuo: {'n_estimators': 57, 'max_depth': 10, 'min_samples_split': 5}
# 2026-02-06 10:55:10,774 | INFO | treinamento | --- Geracao 3/3 ---
# 2026-02-06 10:55:10,774 | INFO | treinamento | Avaliando individuo: {'n_estimators': 57, 'max_depth': 10, 'min_samples_split': 5}
# 2026-02-06 10:55:10,933 | INFO | treinamento | Fitness calculado: 0.8597
# 2026-02-06 10:55:10,933 | INFO | treinamento | Avaliando individuo: {'n_estimators': 57, 'max_depth': 10, 'min_samples_split': 10}
# 2026-02-06 10:55:11,097 | INFO | treinamento | Fitness calculado: 0.8451
# 2026-02-06 10:55:11,097 | INFO | treinamento | Avaliando individuo: {'n_estimators': 102, 'max_depth': 8, 'min_samples_split': 8}
# 2026-02-06 10:55:11,340 | INFO | treinamento | Fitness calculado: 0.8407
# 2026-02-06 10:55:11,342 | INFO | treinamento | Avaliando individuo: {'n_estimators': 57, 'max_depth': 8, 'min_samples_split': 7}
# 2026-02-06 10:55:11,484 | INFO | treinamento | Fitness calculado: 0.8379
# 2026-02-06 10:55:11,484 | INFO | treinamento | Avaliando individuo: {'n_estimators': 57, 'max_depth': 10, 'min_samples_split': 6}
# 2026-02-06 10:55:11,633 | INFO | treinamento | Fitness calculado: 0.8595
# 2026-02-06 10:55:11,634 | INFO | treinamento | Melhor indivíduo da geracao: (0.8597069413911519, {'n_estimators': 57, 'max_depth': 10, 'min_samples_split': 5})
# 2026-02-06 10:55:11,634 | INFO | treinamento | Crossover gerou filho: {'n_estimators': 57, 'max_depth': 10, 'min_samples_split': 10}
# 2026-02-06 10:55:11,634 | INFO | root | ETAPA=treinamento_random_forest | TEMPO=0.00s
# 2026-02-06 10:55:11,634 | INFO | treinamento | Mutacao aplicada no individuo: {'n_estimators': 57, 'max_depth': 10, 'min_samples_split': 10}
# 2026-02-06 10:55:11,635 | INFO | treinamento | Crossover gerou filho: {'n_estimators': 57, 'max_depth': 10, 'min_samples_split': 5}
# 2026-02-06 10:55:11,635 | INFO | root | ETAPA=treinamento_random_forest | TEMPO=0.00s
# 2026-02-06 10:55:11,636 | INFO | treinamento | Mutacao aplicada no individuo: {'n_estimators': 57, 'max_depth': 10, 'min_samples_split': 5}
# 2026-02-06 10:55:11,636 | INFO | treinamento | Tempo total de execucao do GA: 3.24 segundos
# 2026-02-06 10:55:11,637 | INFO | treinamento | Melhores parametros encontrados: {'n_estimators': 57, 'max_depth': 10, 'min_samples_split': 5}
# 2026-02-06 10:55:11,702 | INFO | treinamento | OTIMIZADO RF -> acc=0.858 recall=0.851 f1=0.803
# 2026-02-06 10:55:11,732 | INFO | treinamento | Modelos salvos com sucesso!
# 2026-02-06 10:55:11,733 | INFO | treinamento | ===== FIM DA EXECUCAO =====

# %% [markdown]
# Aqui, carregamos os modelos e o escalonador que foram treinados e salvos anteriormente.
# O joblib é usado para ler esses arquivos .pkl que contêm os modelos prontos.

# %%
# Carregar modelos e scaler salvos (insira o diretório)
lr = joblib.load('./outputs/lr_model.pkl')
rf = joblib.load('./outputs/rf_model.pkl')
scaler = joblib.load('./outputs/scaler.pkl')

# %% [markdown]
# Esta função serve para o usuário digitar manualmente os dados de um novo paciente.
# Ela cria um DataFrame com as mesmas colunas do dataset original e realiza o mesmo pré-processamento
# que foi feito no momento do treinamento

# %%
# Função para inserir dados do paciente
def inserir_dados_paciente():
    print("\n=== Avaliação de Risco de Diabetes ===")

    try:
        Pregnancies = int(input("Número de gestações: "))
        Glucose = float(input("Glicose (mg/dL): "))
        BloodPressure = float(input("Pressão arterial (mmHg): "))
        SkinThickness = float(input("Espessura da pele (mm): "))
        Insulin = float(input("Insulina (µU/mL): "))
        BMI = float(input("IMC (BMI): "))
        DiabetesPedigreeFunction = float(input("Função de pedigree diabético: "))
        Age = int(input("Idade: "))

    except ValueError:
        print("\n Entrada invalida, digite apenas numeros.")
        return None

    paciente = pd.DataFrame({
        'Pregnancies':[Pregnancies],
        'Glucose':[Glucose],
        'BloodPressure':[BloodPressure],
        'SkinThickness':[SkinThickness],
        'Insulin':[Insulin],
        'BMI':[BMI],
        'DiabetesPedigreeFunction':[DiabetesPedigreeFunction],
        'Age':[Age]
    })

    # Substitui valores impossíveis
    cols_zero = ['Glucose','BloodPressure','SkinThickness','Insulin','BMI']
    paciente[cols_zero] = paciente[cols_zero].replace(0, np.nan)

    # Preenche com medianas do dataset
    paciente.fillna(df.median(), inplace=True)

    # Escalonamento
    paciente_scaled = scaler.transform(paciente)

    return paciente, paciente_scaled

# %%
# criando um dicionario com os dois modelos treinados
modelos = {'Regressao Logistica': lr, 'Random Forest': rf}

# %% [markdown]
#  --------------- Realizando as Predições ----------------
#  Para cada modelo, o código faz:
# - A previsão (0 = Não Diabetes, 1 = Diabetes)
# - Calcula as probabilidades de cada classe
# - Exibe o resultado formatado

# %%
from utils import gerar_explicacao_llm
# ================================
#     EXECUÇÃO PRINCIPAL
# ================================
paciente_raw, paciente_scaled = inserir_dados_paciente()

if paciente_scaled is None:
    exit()

modelos = {
    'Regressão Logística': lr,
    'Random Forest': rf
}

print("\n==============================")
print("      RESULTADOS")
print("==============================")

for nome, modelo in modelos.items():
    pred = modelo.predict(paciente_scaled)
    proba = modelo.predict_proba(paciente_scaled)

print(f"\n {nome}")
print("------------------------------")

pred_texto = "Positivo para risco de diabetes" if pred[0] == 1 else "Negativo para risco de diabetes"
print("Predição:", pred_texto)

classes = ['Não Diabetes', 'Diabetes']
for i, p in enumerate(proba[0]):
    print(f"{classes[i]}: {p*100:.2f}%")

# -------- LLM EXPLICA RESULTADO --------
try:
    explicacao = gerar_explicacao_llm(
        predicao=pred_texto,
        probabilidades={classes[i]: float(proba[0][i]) for i in range(len(classes))},
        paciente_info=paciente_raw.to_dict(orient="records")[0],
        metricas_modelo="Avaliação baseada no modelo treinado."
    )

    print("\n Interpretação da i.a:")
    print("-------------------------------------")
    print(explicacao)

except Exception as e:
    print("\n Não foi possível gerar explicação da IA.")
    print(e)
# Out:
# === Avaliação de Risco de Diabetes ===
#
# ==============================
#       RESULTADOS
# ==============================
#
#  Random Forest
# ------------------------------
# Predição: Negativo para risco de diabetes
# Não Diabetes: 84.00%
# Diabetes: 16.00%
# 2026-02-06 10:55:53,487 | INFO | httpx | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
#
#  Interpretação da i.a:
# -------------------------------------
# O paciente apresenta um histórico de 5 gestações e dados laboratoriais que indicam níveis elevados de glicose (19.0) e pressão arterial (1110.0), além de um índice de massa corporal (BMI) de 19.0, que está abaixo do intervalo considerado saudável. A espessura da pele é de 3.0 mm e os níveis de insulina são de 129.0, enquanto a função genética relacionada ao diabetes apresenta um valor de 1.0. Apesar da predição negativa para risco de diabetes, com 84% de probabilidade de não diabetes e 16% de probabilidade de diabetes, a combinação de fatores como a glicose elevada e a história gestacional pode sugerir um risco aumentado de desregulação glicêmica, necessitando de monitoramento contínuo.
